# %%
import sqlite3 as sq

# %%
connection=sq.connect('example.db')
connection

# %%
cursor=connection.cursor()

# %%
cursor.execute(''Create Table If Note Exists employees(id Integrer Primary Key,
    name Text Not Null,
    age Integer,
    department Text''))
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cursor.execute('''
#       2 Create Table If Note Exists employees(
#       3     id Integrer Primary Key,
#       4     name Text Not Null,
#       5     age Integer,
#       6     department Text
#       7
#       8     )
#       9 ''')
#      10 connection.commit()
#
# OperationalError: near "Note": syntax error
