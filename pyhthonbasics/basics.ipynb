# %% [markdown]
# #basics of python

# %%
#print a word 
print("hello word")
print("vivek mane")
# Out:
# hello word
# vivek mane

# %%
#single line comment 
'''multi line comment
used trippel qutes
'''
# Out:
# 'multi line comment\nused trippel qutes\n'

# %%
#varriable decleration
#do not need to define data type of var the automatic detect
a=10
b="vivek"
type(a)
type(b)
# Out:
# str

# %%
first_name="vivek"
print(first_name)
# Out:
# vivek

# %%
#integer
a=5
print(type(a))
print("add",a+10)
print("sub",a-3)
print("mul",a*2)
print("div",a/2)
# Out:
# <class 'int'>
# add 15
# sub 2
# mul 10
# div 2.5

# %%
#floating
f=12.2
print(type(f))
# Out:
# <class 'float'>

# %%
#typecast
int(f)
# Out:
# 12

# %%
#Boolean
B=True
B1=False
print(type(B))
print(B & B1)
print(B | B1)
# Out:
# <class 'bool'>
# False
# True

# %%
#String
name="vivek"
print(type(name))
print(name)
# Out:
# <class 'str'>
# vivek

# %%
#concatenation
print(name + "mane")

#concatenate diffrant data types
name + str(4)
# Out:
# vivekmane
# 'vivek4'

# %%
#dynamic typing
a=10
print(type(a))
a="vivek"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#String formating
first_name="vivek"
last_name="mane"
print("the first name is {0} and last name is {1}".format(first_name,last_name))
# Out:
# the first name is vivek and last name is mane

# %%
#user Input
#defualt these is string format
input("enter name")

#type cast in int
a=int(input("enter the number"))
b=int(input("enter the number"))
print(a+b)
# Out:
# 50
